# %% [markdown]
# <a href="https://colab.research.google.com/github/KietHuynh02/EXERCISE_WEEK_2/blob/main/EXERCISE_WEEK_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url= 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)

# %%
data[data['NOC']=='AUT']
# Out:
#       Year        City    Sport       Discipline  NOC                  Event  \
# 0     1924    Chamonix  Skating   Figure skating  AUT             individual
# 1     1924    Chamonix  Skating   Figure skating  AUT             individual
# 2     1924    Chamonix  Skating   Figure skating  AUT                  pairs
# 49    1928  St. Moritz  Skating   Figure skating  AUT             individual
# 50    1928  St. Moritz  Skating   Figure skating  AUT             individual
# ...    ...         ...      ...              ...  ...                    ...
# 2079  2006       Turin   Skiing  Nordic Combined  AUT                   Team
# 2080  2006       Turin   Skiing      Ski Jumping  AUT  K120 individual (90m)
# 2081  2006       Turin   Skiing      Ski Jumping  AUT  K120 individual (90m)
# 2082  2006       Turin   Skiing      Ski Jumping  AUT        K120 team (90m)
# 2083  2006       Turin   Skiing        Snowboard  AUT  Giant parallel slalom
#
#      Event gender   Medal
# ...

# %%
data_AUT = data[data['NOC']=='AUT'].count()
data_AUT
# Out:
# Year            185
# City            185
# Sport           185
# Discipline      185
# NOC             185
# Event           185
# Event gender    185
# Medal           185
# dtype: int64

# %%
data[(data['NOC']=='AUT')&(data['Medal']=='Gold')] # nước Úc có huy chương vàng
# Out:
#       Year                    City      Sport       Discipline  NOC  \
# 1     1924                Chamonix    Skating   Figure skating  AUT
# 2     1924                Chamonix    Skating   Figure skating  AUT
# 90    1932             Lake Placid    Skating   Figure skating  AUT
# 133   1936  Garmisch-Partenkirchen    Skating   Figure skating  AUT
# 186   1948              St. Moritz     Skiing    Alpine Skiing  AUT
# 254   1952                    Oslo     Skiing    Alpine Skiing  AUT
# 258   1952                    Oslo     Skiing    Alpine Skiing  AUT
# 319   1956       Cortina d'Ampezzo    Skating   Figure skating  AUT
# 321   1956       Cortina d'Ampezzo     Skiing    Alpine Skiing  AUT
# 323   1956       Cortina d'Ampezzo     Skiing    Alpine Skiing  AUT
# 327   1956       Cortina d'Ampezzo     Skiing    Alpine Skiing  AUT
# 393   1960            Squaw Valley     Skiing    Alpine Skiing  AUT
# 472   1964               Innsbruck       Luge             Luge  AUT
# ...

# %%
data[(data['NOC']=='AUT')&(data['Medal']=='Silver')] # nước Úc có huy chương bạc
# Out:
#       Year         City    Sport       Discipline  NOC                  Event  \
# 0     1924     Chamonix  Skating   Figure skating  AUT             individual
# 49    1928   St. Moritz  Skating   Figure skating  AUT             individual
# 50    1928   St. Moritz  Skating   Figure skating  AUT             individual
# 52    1928   St. Moritz  Skating   Figure skating  AUT                  pairs
# 91    1932  Lake Placid  Skating   Figure skating  AUT             individual
# ...    ...          ...      ...              ...  ...                    ...
# 2070  2006        Turin   Skiing    Alpine Skiing  AUT                 slalom
# 2072  2006        Turin   Skiing    Alpine Skiing  AUT                 slalom
# 2073  2006        Turin   Skiing    Alpine Skiing  AUT                super-G
# 2077  2006        Turin   Skiing  Nordic Combined  AUT             Individual
# 2081  2006        Turin   Skiing      Ski Jumping  AUT  K120 individual (90m)
#
#      Event gender   Medal
# ...

# %%
data[(data['NOC']=='AUT')&(data['Medal']=='Bronze')] # nước Úc có huy chương đồng
# Out:
#       Year                    City    Sport       Discipline  NOC  \
# 51    1928              St. Moritz  Skating   Figure skating  AUT
# 132   1936  Garmisch-Partenkirchen  Skating   Figure skating  AUT
# 135   1936  Garmisch-Partenkirchen  Skating    Speed skating  AUT
# 183   1948              St. Moritz  Skating   Figure skating  AUT
# 185   1948              St. Moritz   Skiing    Alpine Skiing  AUT
# ...    ...                     ...      ...              ...  ...
# 2068  2006                   Turin   Skiing    Alpine Skiing  AUT
# 2071  2006                   Turin   Skiing    Alpine Skiing  AUT
# 2074  2006                   Turin   Skiing    Alpine Skiing  AUT
# 2076  2006                   Turin   Skiing  Cross Country S  AUT
# 2083  2006                   Turin   Skiing        Snowboard  AUT
#
#                       Event Event gender   Medal
# 51                    pairs            X  Bronze
# 132              individual            M  Bronze
# ...

# %%
data['Year'].unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
data['City'].unique()
# Out:
# array(['Chamonix', 'St. Moritz', 'Lake Placid', 'Garmisch-Partenkirchen',
#        'Oslo', "Cortina d'Ampezzo", 'Squaw Valley', 'Innsbruck',
#        'Grenoble', 'Sapporo', 'Sarajevo', 'Calgary', 'Albertville',
#        'Lillehammer', 'Nagano', 'Salt Lake City', 'Turin'], dtype=object)

# %%
data['Discipline'].unique()
# Out:
# array(['Figure skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon',
#        'Speed skating', 'Cross Country S', 'Curling', 'Nordic Combined',
#        'Ski Jumping', 'Skeleton', 'Alpine Skiing', 'Luge',
#        'Short Track S.', 'Freestyle Ski.', 'Snowboard'], dtype=object)

# %%
data['Event'].unique()
# Out:
# array(['individual', 'pairs', 'four-man', 'ice hockey', 'military patrol',
#        '10000m', '1500m', '5000m', '500m', 'combined (4 events)', '18km',
#        'curling', '50km', 'K90 individual (70m)', 'five-man', 'two-man',
#        '4x10km relay', 'alpine combined', 'downhill', 'slalom',
#        'giant slalom', '10km', '30km mass start', '3x5km relay', '15km',
#        '1000m', '20km', '3000m', 'doubles', 'singles', '5km',
#        'K120 individual (90m)', '4x7.5km relay', '4x5km relay',
#        'ice dancing', 'super-G', 'Team', 'K120 team (90m)', '3000m relay',
#        '5000m relay', '3x7.5km relay', '7.5km', '15km mass start', '30km',
#        'Combined 5km + 10km pursuit', 'moguls', '10km pursuit',
#        'Combined 10km + 15km pursuit', 'aerials', 'giant-slalom',
#        'Half-pipe', 'sprint', '5km pursuit', '12.5km pursuit',
#        'Giant parallel slalom', 'Sprint 1.5km', 'sprint 1.5km',
#        'Alpine combined', 'Individual', 'Individual sprint',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2311 non-null   int64
#  1   City          2311 non-null   object
#  2   Sport         2311 non-null   object
#  3   Discipline    2311 non-null   object
#  4   NOC           2311 non-null   object
#  5   Event         2311 non-null   object
#  6   Event gender  2311 non-null   object
#  7   Medal         2311 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 144.6+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
# %%
data[(data['NOC']=='AUT')&(data['Discipline']=='Snowboard')]
# Out:
#       Year    City   Sport Discipline  NOC                  Event  \
# 1637  1998  Nagano  Skiing  Snowboard  AUT           giant-slalom
# 2083  2006   Turin  Skiing  Snowboard  AUT  Giant parallel slalom
#
#      Event gender   Medal
# 1637            W  Bronze
# 2083            M  Bronze

# %%
data[(data['NOC']=='AUT')&(data['Discipline']=='Freestyle Ski')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
data[(data['NOC']=='AUT')&(data['Discipline']=='Short Track S')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
data[(data['Medal']=='Gold')&(data['NOC']=='AUT')].min()
# Out:
# Year                     1924
# City              Albertville
# Sport               Bobsleigh
# Discipline      Alpine Skiing
# NOC                       AUT
# Event                   1500m
# Event gender                M
# Medal                    Gold
# dtype: object

# %%
data[(data['Medal']=='Gold')&(data['NOC']=='AUT')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       AUT
# Event                 super-G
# Event gender                X
# Medal                    Gold
# dtype: object

# %%
data[(data['Medal']=='Silver')&(data['NOC']=='AUT')].min()
# Out:
# Year                     1924
# City              Albertville
# Sport               Bobsleigh
# Discipline      Alpine Skiing
# NOC                       AUT
# Event                  10000m
# Event gender                M
# Medal                  Silver
# dtype: object

# %%
data[(data['Medal']=='Silver')&(data['NOC']=='AUT')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       AUT
# Event                 super-G
# Event gender                X
# Medal                  Silver
# dtype: object

# %%
data[(data['Medal']=='Bronze')&(data['NOC']=='AUT')].min()
# Out:
# Year                     1928
# City              Albertville
# Sport                Biathlon
# Discipline      Alpine Skiing
# NOC                       AUT
# Event                  10000m
# Event gender                M
# Medal                  Bronze
# dtype: object

# %%
data[(data['Medal']=='Bronze')&(data['NOC']=='AUT')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       AUT
# Event                 super-G
# Event gender                X
# Medal                  Bronze
# dtype: object

# %%
ex3=data.groupby(['Medal'])['Medal'].count()
sum=data.groupby(['Medal'])['Medal'].count().sum()
mean=data.groupby(['Medal'])['Medal'].count().mean()
max=data.groupby(['Medal'])['Medal'].count().max()
min=data.groupby(['Medal'])['Medal'].count().min()
print("Gia tri nho nhat \n",min)
print("Gia tri lon nhat \n",max)
print("Gia tri trung binh \n",mean)
print("Gia tri tong \n",sum)
# Out:
# Gia tri nho nhat
#  764
# Gia tri lon nhat
#  774
# Gia tri trung binh
#  770.3333333333334
# Gia tri tong
#  2311

# %%
data.groupby((data['NOC']=='AUT')&(data['Discipline']))['Medal'].count()
# Out:
# False    2126
# True      185
# Name: Medal, dtype: int64
